# %% [markdown]
# <a href="https://colab.research.google.com/github/Vansh11112003/RL_21csu109/blob/main/Correlation1_RL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
np.random.seed(1)

# %%
x=np.random.randint(0,50,1000)
x
# Out:
# array([23,  1, 49, 13,  3,  0, 13,  6, 21,  6,  2, 12, 27, 21, 11,  7, 13,
#         8, 11, 12, 43, 20, 30, 36, 39,  7, 45,  4, 48, 18, 32, 13, 10, 23,
#        17,  7, 24, 10, 28, 20, 32, 12,  1, 30, 41, 24, 18, 33,  2, 44, 28,
#        39, 34, 10, 32, 41, 18, 22,  6,  2,  7, 39, 48, 15,  5, 17, 42, 20,
#        48, 22, 37, 13, 49, 33, 20, 10, 32, 25, 21, 39, 32, 19, 25, 49, 14,
#        13, 20, 43,  6, 13, 15, 24,  9,  2,  7,  5, 36, 37, 21, 40, 13, 27,
#        49, 49, 47, 13, 40, 14, 45, 23, 16, 28, 42, 45,  3,  2, 14, 46,  0,
#        29, 11, 35, 29, 33,  2, 20, 19, 48, 32, 28, 18, 31, 28, 30, 10,  8,
#        45, 35, 32,  8, 20, 13, 15, 41,  0, 44, 19, 24, 49, 42, 20, 44, 15,
#        30, 27, 14, 19, 26, 43, 22,  7, 35, 47, 46, 34, 36, 36, 32, 19,  3,
#        24, 19, 37, 30, 38, 47, 39,  5, 15, 49, 23, 32, 42, 10,  2, 24, 34,
#        30, 17,  4,  0, 14, 17, 39, 35, 17, 28, 22, 38, 41, 10, 13,  6, 25,
# ...

# %%
y=x+np.random.normal(0,10,1000)
y
# Out:
# array([ 1.58988348e+01, -9.03677010e+00,  5.01424793e+01,  2.31375566e+01,
#        -4.20034693e+00, -4.24656445e+00,  2.12006883e+01, -9.11322896e+00,
#         1.62489285e+01, -1.35950744e+01,  1.45764523e+01,  9.85817494e+00,
#         8.30291120e+00,  1.20754078e+01,  4.03283536e-02,  1.38851267e+01,
#        -6.47256923e+00,  4.55675046e+00,  2.00495867e+01,  1.50421596e+01,
#         5.75531938e+01,  1.73237045e+01,  5.04670864e+01,  3.03622192e+01,
#         3.70717909e+01, -3.59241331e+00,  4.70455563e+01,  1.19377953e+01,
#         4.82792344e+01,  3.38474465e+01,  4.42823695e+01,  1.29303542e+01,
#         1.12125851e+01,  1.58476234e+01,  1.72801257e+01,  1.39445039e+01,
#         2.81641650e+01,  6.34334363e+00,  3.64179769e+01,  9.58433100e+00,
#         3.84222491e+01,  1.25760804e+01,  1.17525473e+01,  3.39556907e+01,
#         3.87065843e+01,  1.85551617e+01,  2.06566099e+01,  3.53735883e+01,
# ...

# %%
np.corrcoef(x,y)
# Out:
# array([[1.        , 0.82050191],
#        [0.82050191, 1.        ]])

# %%
from io import IncrementalNewlineDecoder
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')

plt.scatter(x,y)
plt.show()

# %%
y=x-np.random.normal(0,10,1000)
y
# Out:
# array([ 26.4182972 ,  -0.38250518,  59.34843108,   8.05312272,
#          6.55604992,   1.23964072,  24.98599833,   5.68605084,
#         14.12316722,   5.64324131,   4.94769114,   2.013081  ,
#         17.40231993,  28.92561618,  18.96791659,  15.41363496,
#         -7.64024301,  25.40482482,   2.78822304,   5.44387664,
#         56.17076404,  22.188725  ,  28.93665879,  29.82907418,
#         36.24138799,  -2.53850425,  53.4389425 ,  14.27973564,
#         42.48795638,  17.60727302,  31.57466876,  26.55715784,
#         -1.89762495,  29.89052991,  20.3183385 ,  -6.32200857,
#         30.38569973,  18.45495995,  18.16214223,  17.39502998,
#         20.7322461 ,   3.47012787,   1.48378511,  27.2155818 ,
#         21.1980418 ,  20.51021608,  37.0377593 ,  31.77984605,
#          5.12573197,  49.73522132,  21.4442927 ,  26.4805603 ,
#         33.19395616,  -4.18681127,  25.77653866,  54.02938458,
#         19.71385179,  13.31927517,  -9.8155958 ,   6.84260027,
# ...

# %%
np.corrcoef(x,y)
# Out:
# array([[1.        , 0.82469051],
#        [0.82469051, 1.        ]])

# %%
plt.scatter(x,y)
plt.show()

# %%
y=100-x+np.random.normal(0,5,1000)
y
# Out:
# array([ 75.20576896, 101.95415205,  44.16496406,  81.47626681,
#         90.3184401 , 101.10876163,  93.31141529,  85.06149051,
#         79.19709166,  89.20616317,  95.58287835,  84.23610676,
#         74.496508  ,  83.3510189 ,  89.48332371,  95.24741118,
#         86.88445323,  91.32818766, 102.25884348,  84.77134515,
#         58.72014215,  72.28709568,  70.78032273,  51.54271162,
#         58.79750336,  91.04913395,  51.10862221, 101.82509345,
#         56.43214244,  91.76380755,  60.99778992,  85.65088635,
#         97.06951571,  83.82960801,  85.91586861,  94.37693511,
#         78.81083294,  96.33954815,  65.35552167,  82.33554331,
#         73.40229103,  90.60006135,  90.88055327,  72.06560649,
#         65.7298986 ,  76.54532093,  82.91171043,  79.76273118,
#        100.61066922,  45.53117726,  69.97970162,  61.26112295,
#         64.6387222 ,  91.18779496,  67.80402472,  56.55783354,
#         84.20443076,  80.21409411,  81.59829259,  92.49561875,
# ...

# %%
np.corrcoef(x,y)
# Out:
# array([[ 1.        , -0.94011862],
#        [-0.94011862,  1.        ]])

# %%
plt.scatter(x,y)

# %%
y=np.random.randint(0,25,1000)

z=y-np.random.normal(0,20,1000)
z
# Out:
# array([ 2.50067929e+01,  8.14023785e+00, -1.59606451e+01, -1.16675307e+01,
#        -2.57637087e+01,  2.54327498e+01, -9.09317461e+00,  3.42942219e+00,
#         4.34239772e+00,  4.76946189e+00, -6.34633540e+00,  4.59526645e+01,
#         2.19722740e+01, -1.62085746e+00, -1.15680342e+01,  6.95318998e+00,
#         3.63088191e+01,  3.95689535e+01,  1.23641273e+01,  5.61505933e+01,
#         4.72949432e+00,  1.23068710e+01,  1.99083922e+01,  2.62140492e+01,
#         3.99086760e+01,  1.29257602e+01, -1.61754438e+01,  1.19132289e+01,
#         1.82929391e+01,  1.29120439e+01,  2.93144455e+00, -6.77644674e+00,
#         3.94173964e+01,  1.67171028e+01,  1.49451522e+01, -4.99085462e+00,
#        -2.71343054e+01,  3.00983662e+01, -2.88346985e+00, -1.95373126e+01,
#        -7.31861298e-01,  7.35228207e+00,  4.04626703e+01, -1.95962558e+01,
#         1.31405609e+01, -2.41620164e+01, -2.07815337e+01,  3.16512861e+01,
# ...

# %%
np.corrcoef(y,z)
# Out:
# array([[1.        , 0.36682254],
#        [0.36682254, 1.        ]])

# %%
plt.scatter(y,z)

# %%
x=np.random.randint(0,50,1000)
y=np.random.randint(0,50,1000)

np.corrcoef(x,y)
# Out:
# array([[ 1.        , -0.00936046],
#        [-0.00936046,  1.        ]])

# %%
plt.scatter(x,y)

# %%
import pandas as pd

df = pd.DataFrame({'a':np.random.randint(0,50,1000)})
df['b']=df['a']+np.random.normal(0,10,1000)
df['c']=100-df['a']+np.random.normal(0,5,1000)
df['d']=np.random.randint(0,50,1000)

df.corr()
# Out:
#           a         b         c         d
# a  1.000000  0.832245 -0.947665 -0.026309
# b  0.832245  1.000000 -0.787263 -0.009994
# c -0.947665 -0.787263  1.000000  0.026118
# d -0.026309 -0.009994  0.026118  1.000000

# %%
pd.plotting.scatter_matrix(df,figsize=(6,6))
plt.show()

# %%
plt.matshow(df.corr())
plt.xticks(range(len(df.columns)),df.columns)
plt.yticks(range(len(df.columns)),df.columns)
plt.colorbar()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
